# %%
avl = [33, 64, 549, 1585, 2427, 8065, 31523, 59873]
bst = [28, 38, 406, 1174, 2006, 8306, 33509, 64924]
rb = [35, 38, 366, 1130, 1983, 7663, 28669, 54653]

counts = [10,100,1000,3000,5000,20000, 60000, 100000]

# %%
from matplotlib import pyplot as plt

plt.plot(counts,bst, '-o')

plt.plot(counts, avl, '-o')
plt.plot(counts, rb, '-o')
plt.legend(['bst','avl','rb'])

plt.show()

# %%
bst = [7, 14, 27, 24, 26, 31, 44, 43]
avl = [5, 10, 13, 16, 17, 18, 20, 21]
rb = [7, 14, 19, 24, 29, 33, 37, 41]

counts = [10,100,1000,3000,5000,20000, 60000, 100000]

# %%
plt.plot(counts,bst, '-o')

plt.plot(counts, avl, '-o')
plt.plot(counts, rb, '-o')
plt.legend(['bst','avl','rb'])

plt.show()
