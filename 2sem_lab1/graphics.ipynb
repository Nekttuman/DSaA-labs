# %%
bst = [49, 67, 441, 1209, 2021, 11020, 85854]
avl = [27, 36, 369, 1321, 2004, 7812, 77315]
rb = [40, 47, 473, 1482, 2902, 8861, 71925]

counts = [10,100,1000,3000,5000,20000,100000]

# %%
from matplotlib import pyplot as plt

plt.plot(bst, counts,'-o')

plt.plot(avl, counts,'-o')
plt.plot(rb, counts,'-o')
plt.legend(['bst','avl','rb'])

plt.show()
